# %%
import os
import pandas as pd
# import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

current_directory = os.getcwd()

# %%
testlogV2 = pd.read_csv(current_directory + r"\V2\testlog.csv")
testlogV3 = pd.read_csv(current_directory + r"\V3\testlog.csv")

# %%
testlogV2.head()
# Out:
#    Matrix_size   Time_Comsuming(ms)
# 0          100                3.273
# 1          200               24.080
# 2          300               75.740
# 3          400              166.300
# 4          500              320.290

# %%
testlogV3.head()
# Out:
#    Matrix_size   Time_Comsuming(ms)
# 0          100                0.857
# 1          200                8.167
# 2          300               28.689
# 3          400               77.361
# 4          500              135.396

# %%
ax = testlogV2.plot(x = "Matrix_size", legend = False, xlabel="Matrix Size", ylabel="Time Comsuming(ms)")
testlogV3.plot(x = "Matrix_size", legend = False, ax = ax)
ax.legend(["No optimal options", "-O3 optimal"])
ax.grid()
fig = ax.get_figure()
fig.tight_layout()
fig.savefig(current_directory + r"\testlog.svg")
None
